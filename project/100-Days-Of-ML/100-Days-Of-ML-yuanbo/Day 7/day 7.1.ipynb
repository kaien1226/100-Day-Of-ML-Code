# %%
from IPython.display import Image
Image(filename = '/home/zhengyuanbo/project/100-Days-Of-ML/100-Days-Of-ML-yuanbo/Day 7/KNN.jpg')

# %% [markdown]
# As shown up, the green circle is determined to be assigned to which class, is it a red triangle or a blue square? If K=3, since the proportion of the red triangle is 2/3, the green circle will be given the red triangle. If K=5, the blue circle is given the blue four because the ratio of the blue square is 3/5. Square class.
#
#
# Reference page https://www.cnblogs.com/pinard/p/6065607.html

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.datasets.samples_generator import make_classification

# %% [markdown]
# ## Generate samples and labels data sets

# %%
X, Y = make_classification(n_samples=1000, n_features=2, n_redundant=0,
                             n_clusters_per_class=1, n_classes=3)
plt.scatter(X[:, 0], X[:, 1], marker='o', c=Y)
plt.show()

# %% [markdown]
# ## Fitting K-NN to the data set

# %%
from sklearn import neighbors
clf = neighbors.KNeighborsClassifier(n_neighbors = 15 , weights='distance')
clf.fit(X, Y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=15, p=2,
#            weights='distance')

# %% [markdown]
# ## Set train set boundaries

# %%
from matplotlib.colors import ListedColormap
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])


x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1

xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.02),
                         np.arange(y_min, y_max, 0.02))
Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
print(xx)
print(yy)
print(Z)
# Out:
# [[-4.30690407 -4.28690407 -4.26690407 ...  2.31309593  2.33309593
#    2.35309593]
#  [-4.30690407 -4.28690407 -4.26690407 ...  2.31309593  2.33309593
#    2.35309593]
#  [-4.30690407 -4.28690407 -4.26690407 ...  2.31309593  2.33309593
#    2.35309593]
#  ...
#  [-4.30690407 -4.28690407 -4.26690407 ...  2.31309593  2.33309593
#    2.35309593]
#  [-4.30690407 -4.28690407 -4.26690407 ...  2.31309593  2.33309593
#    2.35309593]
#  [-4.30690407 -4.28690407 -4.26690407 ...  2.31309593  2.33309593
#    2.35309593]]
# [[-3.95483029 -3.95483029 -3.95483029 ... -3.95483029 -3.95483029
#   -3.95483029]
#  [-3.93483029 -3.93483029 -3.93483029 ... -3.93483029 -3.93483029
#   -3.93483029]
#  [-3.91483029 -3.91483029 -3.91483029 ... -3.91483029 -3.91483029
#   -3.91483029]
#  ...
#  [ 4.28516971  4.28516971  4.28516971 ...  4.28516971  4.28516971
#    4.28516971]
#  [ 4.30516971  4.30516971  4.30516971 ...  4.30516971  4.30516971
#    4.30516971]
# ...

# %%
# 画出测试集数据
Z = Z.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

# 也画出所有的训练集数据
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=cmap_bold)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("3-Class classification (k = 15, weights = 'distance')" )
# Out:
# Text(0.5,1,"3-Class classification (k = 15, weights = 'distance')")
